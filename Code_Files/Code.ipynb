# %%
'''Import functions from pyspark.sql.functions'''
from pyspark.sql.functions import col, count, avg, sum as spark_sum, desc, when, year, spark_partition_id

# %%
'''Read the customers, orders, order_items, products, and product_reviews tables in as spark dataframes''' 
customers_df = spark.read.csv("/Volumes/workspace/default/synthetic_e_commerce_data/customers.csv", header=True, inferSchema=True)
orders_df = spark.read.csv("/Volumes/workspace/default/synthetic_e_commerce_data/orders.csv", header=True, inferSchema=True)
order_items_df = spark.read.csv("/Volumes/workspace/default/synthetic_e_commerce_data/order_items.csv", header=True, inferSchema=True)
products_df = spark.read.csv("/Volumes/workspace/default/synthetic_e_commerce_data/products.csv", header=True, inferSchema=True)
product_reviews_df = spark.read.csv("/Volumes/workspace/default/synthetic_e_commerce_data/product_reviews.csv", header=True, inferSchema=True)

customers_df.show(5)
orders_df.show(5)
order_items_df.show(5)
products_df.show(5)
product_reviews_df.show(5)
# Out:
# +-----------+---------------+--------------------+------+-----------+----------+
# |customer_id|           name|               email|gender|signup_date|   country|
# +-----------+---------------+--------------------+------+-----------+----------+
# |          1|   Allison Hill|donaldgarcia@exam...| Other| 2025-02-15|     Benin|
# |          2|   Amanda Davis|williamjohnson@ex...|  Male| 2024-03-30|   Reunion|
# |          3|Connie Lawrence|blakeerik@example...|  Male| 2022-05-13|Cape Verde|
# |          4| Phillip Garcia|  wdavis@example.net| Other| 2021-12-26|     Aruba|
# |          5|Kimberly Dudley| smiller@example.net|Female| 2023-10-04|   Tokelau|
# +-----------+---------------+--------------------+------+-----------+----------+
# only showing top 5 rows
# +--------+-----------+----------+------------+--------------+----------------+
# |order_id|customer_id|order_date|total_amount|payment_method|shipping_country|
# +--------+-----------+----------+------------+--------------+----------------+
# |       1|     331090|2025-05-12|      774.46|   Credit Card|        Pakistan|
# |       2|     208473|2022-12-31|       757.8| Bank Transfer|   Liechtenstein|
# |       3|     847096|2021-09-19|     2355.87|   Credit Card|       Sri Lanka|
# |       4|    1919911|2024-10-21|      776.77|   Credit Card|       Sri Lanka|
# |       5|     281685|2024-10-26|         0.0|          Cash|      Costa Rica|
# +--------+-----------+----------+------------+--------------+----------------+
# only showing top 5 rows
# +-------------+--------+----------+--------+----------+
# |order_item_id|order_id|product_id|quantity|unit_price|
# +-------------+--------+----------+--------+----------+
# |            1| 6373838|      4999|       4|    498.31|
# |            2|  831217|     19254|       5|    298.43|
# |            3| 4870008|     14862|       2|    404.92|
# |            4| 6105609|      9893|       5|    225.24|
# |            5| 5466713|     17378|       4|     10.23|
# +-------------+--------+----------+--------+----------+
# only showing top 5 rows
# +----------+---------------+--------+------+--------------+------+
# |product_id|   product_name|category| price|stock_quantity| brand|
# +----------+---------------+--------+------+--------------+------+
# |         1|       Plan Get|   Books|278.27|           533|BrandA|
# |         2|      Field Yet|  Beauty|479.56|             5|BrandA|
# |         3| Technology Her|   Books|332.59|           268|BrandA|
# |         4|    Decade Pick|    Toys|198.16|           944|BrandB|
# |         5|Finally Develop|  Beauty| 307.6|           862|BrandC|
# +----------+---------------+--------+------+--------------+------+
# only showing top 5 rows
# +---------+----------+-----------+------+--------------------+-----------+
# |review_id|product_id|customer_id|rating|         review_text|review_date|
# +---------+----------+-----------+------+--------------------+-----------+
# |        1|      6133|    1800986|     4|Represent indeed ...| 2025-08-04|
# |        2|      3154|     383956|     3|Down note local m...| 2022-04-05|
# |        3|     13907|    1445167|     2|Interview know pr...| 2022-10-24|
# |        4|     11575|    1809449|     1|Their skill towar...| 2023-04-09|
# |        5|     11948|     670817|     1|Charge respond me...| 2025-04-18|
# +---------+----------+-----------+------+--------------------+-----------+
# only showing top 5 rows

# %%
'''Filter the orders dataframe to only include orders made in 2024 with either cash or a credit card'''
filtered_order_pm_df = orders_df.filter((col("payment_method") == "Cash") | ((col("payment_method") == "Credit Card")))
filtered_orders_pm_and_year_df = filtered_order_pm_df.filter(year(col("order_date")) == 2024)
filtered_orders_pm_and_year_df.show(5)
# Out:
# +--------+-----------+----------+------------+--------------+----------------+
# |order_id|customer_id|order_date|total_amount|payment_method|shipping_country|
# +--------+-----------+----------+------------+--------------+----------------+
# |       4|    1919911|2024-10-21|      776.77|   Credit Card|       Sri Lanka|
# |       5|     281685|2024-10-26|         0.0|          Cash|      Costa Rica|
# |      19|     492078|2024-09-18|     1645.81|   Credit Card|          Belize|
# |      28|     395661|2024-04-26|     3786.49|          Cash|      Costa Rica|
# |      43|     220998|2024-09-09|     2053.98|          Cash|  Cayman Islands|
# +--------+-----------+----------+------------+--------------+----------------+
# only showing top 5 rows

# %%
'''Merge the customers, order items, product, product review, and filtered orders dataframes into a single dataframe'''
customer_order_df = customers_df.join(filtered_orders_pm_and_year_df, ['customer_id'], 'inner')
customer_order_review_df = customer_order_df.join(product_reviews_df, ['customer_id'], 'inner')
customer_order_review_product_df = customer_order_review_df.join(products_df, ['product_id'], 'inner')
merged_df = customer_order_review_product_df.join(order_items_df,['order_id'],'inner')
merged_df.show(5)
# Out:
# +--------+----------+-----------+-----------------+--------------------+------+-----------+--------------------+----------+------------+--------------+----------------+---------+------+--------------------+-----------+---------------+--------+------+--------------+------+-------------+----------+--------+----------+
# |order_id|product_id|customer_id|             name|               email|gender|signup_date|             country|order_date|total_amount|payment_method|shipping_country|review_id|rating|         review_text|review_date|   product_name|category| price|stock_quantity| brand|order_item_id|product_id|quantity|unit_price|
# +--------+----------+-----------+-----------------+--------------------+------+-----------+--------------------+----------+------------+--------------+----------------+---------+------+--------------------+-----------+---------------+--------+------+--------------+------+-------------+----------+--------+----------+
# |   15277|      1547|    1657261|     Stacy Lawson| cmartin@example.net|  Male| 2021-09-14|             Ecuador|2024-02-27|      466.38|   Credit Card|          Gambia|  3726438|     1|Front water site ...| 2023-06-03|     Yard Least|    Home| 73.18|           742|BrandA|         6255|     18371|       1|     226.7|
# | 6378324|      5591|    1068832| Valerie Anderson|jessica43@example...|Female| 2025-04-09|               Korea|2024-10-07|     4164.84|   Credit Card|           Spain|   212992|     5|Yet difficult abl...| 2024-11-09|      One Might|    Home|151.87|           678|BrandD|         9653|      8525|       4|    142.53|
# | 2441149|     13382|    1237986|        Cody Hill| sarah56@example.net| Other| 2022-02-11|Sao Tome and Prin...|2024-08-03|     1977.94|          Cash|        Paraguay|    65153|     4|Room parent colle...| 2021-09-07|Military Public|    Toys|248.26|           164|BrandA|        15775|      8489|       4|    407.23|
# | 6501072|     15285|    1492590|  Courtney Thomas|phillip09@example...|  Male| 2025-03-14|Cocos (Keeling) I...|2024-08-23|     1584.95|   Credit Card|   French Guiana|   294052|     4|Step understand v...| 2023-08-17|  Culture Build|  Beauty|493.79|           863|BrandB|        15884|     10579|       2|    420.63|
# | 3875158|      4520|     546324|Christopher Perry|onealleslie@examp...|  Male| 2024-04-20|             Senegal|2024-10-24|     6946.84|          Cash|          Guyana|   926380|     4|Clear hand succes...| 2024-04-15|      Trip Free|Clothing|116.41|           115|BrandD|        26798|        79|       4|    420.14|
# +--------+----------+-----------+-----------------+--------------------+------+-----------+--------------------+----------+------------+--------------+----------------+---------+------+--------------------+-----------+---------------+--------+------+--------------+------+-------------+----------+--------+----------+
# only showing top 5 rows

# %%
'''Create a column for the revenue. Calculate the revenue by taking the product of the quantity of the product that was purchased and the unit price of that product'''
merged_df = merged_df.withColumn('revenue',merged_df.quantity*merged_df.unit_price)
merged_df.select('order_item_id','revenue').show(5)
# Out:
# +-------------+-------+
# |order_item_id|revenue|
# +-------------+-------+
# |         6255|  226.7|
# |         9653| 570.12|
# |        15775|1628.92|
# |        15884| 841.26|
# |        26798|1680.56|
# +-------------+-------+
# only showing top 5 rows

# %%
'''Find the 5 products with the highest average rating'''
avg_product_rating = merged_df.select(['product_name','rating']).groupBy('product_name').agg(avg('rating').alias('avg_rating')).orderBy(desc('avg_rating'))
avg_product_rating.show(5)
# Out:
# +----------------+------------------+
# |    product_name|        avg_rating|
# +----------------+------------------+
# |However Director|               3.9|
# |      Night Word|3.7718446601941746|
# |     Trip Nation| 3.754166666666667|
# |   Wide Remember| 3.746192893401015|
# |      Wall Adult|3.7358490566037736|
# +----------------+------------------+
# only showing top 5 rows

# %%
'''Show number of partitions'''
num_partitions = merged_df.select(spark_partition_id()).distinct().count()
print(num_partitions)
# Out:
# 8

# %%
'''Query 1: Find the 5 categories that have the most products in stock'''
merged_df = merged_df.repartition("category")
merged_df.createOrReplaceTempView("merged_df")

most_in_stock_categories = spark.sql("""
    SELECT category, SUM(stock_quantity) AS total_stock_quantity
    FROM merged_df
    GROUP BY category
    ORDER BY total_stock_quantity DESC
    LIMIT 5
""")

display(most_in_stock_categories)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>total_stock_quantity</th></tr></thead><tbody><tr><td>Clothing</td><td>424487981</td></tr><tr><td>Books</td><td>421463771</td></tr><tr><td>Electronics</td><td>420787899</td></tr><tr><td>Toys</td><td>416349413</td></tr><tr><td>Beauty</td><td>412862861</td></tr></tbody></table></div>

# %%
'''Explain the query plan'''
most_in_stock_categories.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(sortOrder=[total_stock_quantity#11812L DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16884]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(sortOrder=[total_stock_quantity#11812L DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(keys=[category#11183], functions=[sum(stock_quantity#11185)])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage REPARTITION_BY_COL, [id=#16876]
#                               +- PhotonShuffleExchangeSink hashpartitioning(category#11183, 1024)
#                                  +- PhotonProject [category#11183, stock_quantity#11185]
#                                     +- PhotonShuffledHashJoin [order_id#11084], [order_id#11136], Inner, BuildRight
#                                        :- PhotonShuffleExchangeSource
#                                        :  +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16861]
#                                        :     +- PhotonShuffleExchangeSink hashpartitioning(order_id#11084, 1024)
#                                        :        +- PhotonProject [order_id#11084, category#11183, stock_quantity#11185]
#                                        :           +- PhotonBroadcastHashJoin [product_id#11233], [product_id#11181], Inner, BuildRight, false, true
#                                        :              :- PhotonProject [order_id#11084, product_id#11233]
#                                        :              :  +- PhotonShuffledHashJoin [customer_id#11033], [customer_id#11234], Inner, BuildRight
#                                        :              :     :- PhotonProject [customer_id#11033, order_id#11084]
#                                        :              :     :  +- PhotonShuffledHashJoin [customer_id#11033], [customer_id#11085], Inner, BuildLeft
#                                        :              :     :     :- PhotonShuffleExchangeSource
#                                        :              :     :     :  +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16822]
#                                        :              :     :     :     +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11033, 1024)
#                                        :              :     :     :        +- PhotonFilter isnotnull(customer_id#11033)
#                                        :              :     :     :           +- PhotonRowToColumnar
#                                        :              :     :     :              +- FileScan csv [customer_id#11033] Batched: false, DataFilters: [isnotnull(customer_id#11033)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/customers.csv], PartitionFilters: [], PushedFilters: [IsNotNull(customer_id)], ReadSchema: struct<customer_id:int>
#                                        :              :     :     +- PhotonShuffleExchangeSource
#                                        :              :     :        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16831]
#                                        :              :     :           +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11085, 1024)
#                                        :              :     :              +- PhotonProject [order_id#11084, customer_id#11085]
#                                        :              :     :                 +- PhotonFilter ((((isnotnull(order_date#11086) AND isnotnull(customer_id#11085)) AND isnotnull(order_id#11084)) AND (year(order_date#11086) = 2024)) AND payment_method#11088 IN (Cash,Credit Card))
#                                        :              :     :                    +- PhotonRowToColumnar
#                                        :              :     :                       +- FileScan csv [order_id#11084,customer_id#11085,order_date#11086,payment_method#11088] Batched: false, DataFilters: [isnotnull(order_date#11086), isnotnull(customer_id#11085), isnotnull(order_id#11084), (year(orde..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/orders.csv], PartitionFilters: [], PushedFilters: [IsNotNull(order_date), IsNotNull(customer_id), IsNotNull(order_id), In(payment_method, [Cash,Cre..., ReadSchema: struct<order_id:int,customer_id:int,order_date:date,payment_method:string>
#                                        :              :     +- PhotonShuffleExchangeSource
#                                        :              :        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16842]
#                                        :              :           +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11234, 1024)
#                                        :              :              +- PhotonFilter (isnotnull(customer_id#11234) AND isnotnull(product_id#11233))
#                                        :              :                 +- PhotonRowToColumnar
#                                        :              :                    +- FileScan csv [product_id#11233,customer_id#11234] Batched: false, DataFilters: [isnotnull(customer_id#11234), isnotnull(product_id#11233)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/product_revi..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id), IsNotNull(product_id)], ReadSchema: struct<product_id:int,customer_id:int>
#                                        :              +- PhotonShuffleExchangeSource
#                                        :                 +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#16854]
#                                        :                    +- PhotonShuffleExchangeSink SinglePartition
#                                        :                       +- PhotonFilter isnotnull(product_id#11181)
#                                        :                          +- PhotonRowToColumnar
#                                        :                             +- FileScan csv [product_id#11181,category#11183,stock_quantity#11185] Batched: false, DataFilters: [isnotnull(product_id#11181)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/products.csv], PartitionFilters: [], PushedFilters: [IsNotNull(product_id)], ReadSchema: struct<product_id:int,category:string,stock_quantity:int>
#                                        +- PhotonShuffleExchangeSource
#                                           +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#16868]
#                                              +- PhotonShuffleExchangeSink hashpartitioning(order_id#11136, 1024)
#                                                 +- PhotonFilter isnotnull(order_id#11136)
#                                                    +- PhotonRowToColumnar
#                                                       +- FileScan csv [order_id#11136] Batched: false, DataFilters: [isnotnull(order_id#11136)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/order_items...., PartitionFilters: [], PushedFilters: [IsNotNull(order_id)], ReadSchema: struct<order_id:int>
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
'''Write the results to a parquet file'''
most_in_stock_categories.write.mode("overwrite").parquet("/Volumes/workspace/default/synthetic_e_commerce_outputs/most_in_statck_categories")

# %%
'''Query 2: Find the 3 products that have generated the most revenue among female customers'''
merged_df = merged_df.repartition("gender", "product_name")
merged_df.createOrReplaceTempView("merged_df")

most_money_generating_products_women = spark.sql("""
    SELECT product_name, SUM(revenue) AS total_revenue
    FROM merged_df
    WHERE gender = 'Female'
    GROUP BY product_name
    ORDER BY total_revenue DESC
    LIMIT 3
""")

display(most_money_generating_products_women)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>total_revenue</th></tr></thead><tbody><tr><td>Decide Morning</td><td>235148.20000000013</td></tr><tr><td>Under Break</td><td>215501.27</td></tr><tr><td>Alone National</td><td>198856.39999999997</td></tr></tbody></table></div>

# %%
'''Explain the query plan'''
most_money_generating_products_women.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonTopK(sortOrder=[total_revenue#12068 DESC NULLS LAST], partitionOrderCount=0)
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22185]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonTopK(sortOrder=[total_revenue#12068 DESC NULLS LAST], partitionOrderCount=0)
#                      +- PhotonGroupingAgg(keys=[product_name#11182], functions=[finalmerge_sum(merge sum#12245) AS sum(revenue)#12243])
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22177]
#                               +- PhotonShuffleExchangeSink hashpartitioning(product_name#11182, 1024)
#                                  +- PhotonGroupingAgg(keys=[product_name#11182], functions=[partial_sum(revenue#11563) AS sum#12245])
#                                     +- PhotonProject [product_name#11182, revenue#11563]
#                                        +- PhotonShuffleExchangeSource
#                                           +- PhotonShuffleMapStage REPARTITION_BY_COL, [id=#22169]
#                                              +- PhotonShuffleExchangeSink hashpartitioning(gender#11036, product_name#11182, 1024)
#                                                 +- PhotonProject [gender#11036, product_name#11182, revenue#11563]
#                                                    +- PhotonShuffleExchangeSource
#                                                       +- PhotonShuffleMapStage REPARTITION_BY_COL, [id=#22163]
#                                                          +- PhotonShuffleExchangeSink hashpartitioning(category#11183, 1024)
#                                                             +- PhotonProject [gender#11036, product_name#11182, category#11183, (cast(quantity#11138 as double) * unit_price#11139) AS revenue#11563]
#                                                                +- PhotonShuffledHashJoin [order_id#11084], [order_id#11136], Inner, BuildRight
#                                                                   :- PhotonShuffleExchangeSource
#                                                                   :  +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22148]
#                                                                   :     +- PhotonShuffleExchangeSink hashpartitioning(order_id#11084, 1024)
#                                                                   :        +- PhotonProject [gender#11036, order_id#11084, product_name#11182, category#11183]
#                                                                   :           +- PhotonBroadcastHashJoin [product_id#11233], [product_id#11181], Inner, BuildRight, false, true
#                                                                   :              :- PhotonProject [gender#11036, order_id#11084, product_id#11233]
#                                                                   :              :  +- PhotonShuffledHashJoin [customer_id#11033], [customer_id#11234], Inner, BuildRight
#                                                                   :              :     :- PhotonProject [customer_id#11033, gender#11036, order_id#11084]
#                                                                   :              :     :  +- PhotonShuffledHashJoin [customer_id#11033], [customer_id#11085], Inner, BuildLeft
#                                                                   :              :     :     :- PhotonShuffleExchangeSource
#                                                                   :              :     :     :  +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22109]
#                                                                   :              :     :     :     +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11033, 1024)
#                                                                   :              :     :     :        +- PhotonFilter ((isnotnull(customer_id#11033) AND isnotnull(gender#11036)) AND (gender#11036 = Female))
#                                                                   :              :     :     :           +- PhotonRowToColumnar
#                                                                   :              :     :     :              +- FileScan csv [customer_id#11033,gender#11036] Batched: false, DataFilters: [isnotnull(customer_id#11033), isnotnull(gender#11036), (gender#11036 = Female)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/customers.csv], PartitionFilters: [], PushedFilters: [IsNotNull(customer_id), IsNotNull(gender), EqualTo(gender,Female)], ReadSchema: struct<customer_id:int,gender:string>
#                                                                   :              :     :     +- PhotonShuffleExchangeSource
#                                                                   :              :     :        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22118]
#                                                                   :              :     :           +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11085, 1024)
#                                                                   :              :     :              +- PhotonProject [order_id#11084, customer_id#11085]
#                                                                   :              :     :                 +- PhotonFilter ((((isnotnull(order_date#11086) AND isnotnull(customer_id#11085)) AND isnotnull(order_id#11084)) AND (year(order_date#11086) = 2024)) AND payment_method#11088 IN (Cash,Credit Card))
#                                                                   :              :     :                    +- PhotonRowToColumnar
#                                                                   :              :     :                       +- FileScan csv [order_id#11084,customer_id#11085,order_date#11086,payment_method#11088] Batched: false, DataFilters: [isnotnull(order_date#11086), isnotnull(customer_id#11085), isnotnull(order_id#11084), (year(orde..., Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/orders.csv], PartitionFilters: [], PushedFilters: [IsNotNull(order_date), IsNotNull(customer_id), IsNotNull(order_id), In(payment_method, [Cash,Cre..., ReadSchema: struct<order_id:int,customer_id:int,order_date:date,payment_method:string>
#                                                                   :              :     +- PhotonShuffleExchangeSource
#                                                                   :              :        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22129]
#                                                                   :              :           +- PhotonShuffleExchangeSink hashpartitioning(customer_id#11234, 1024)
#                                                                   :              :              +- PhotonFilter (isnotnull(customer_id#11234) AND isnotnull(product_id#11233))
#                                                                   :              :                 +- PhotonRowToColumnar
#                                                                   :              :                    +- FileScan csv [product_id#11233,customer_id#11234] Batched: false, DataFilters: [isnotnull(customer_id#11234), isnotnull(product_id#11233)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/product_revi..., PartitionFilters: [], PushedFilters: [IsNotNull(customer_id), IsNotNull(product_id)], ReadSchema: struct<product_id:int,customer_id:int>
#                                                                   :              +- PhotonShuffleExchangeSource
#                                                                   :                 +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#22141]
#                                                                   :                    +- PhotonShuffleExchangeSink SinglePartition
#                                                                   :                       +- PhotonFilter isnotnull(product_id#11181)
#                                                                   :                          +- PhotonRowToColumnar
#                                                                   :                             +- FileScan csv [product_id#11181,product_name#11182,category#11183] Batched: false, DataFilters: [isnotnull(product_id#11181)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/products.csv], PartitionFilters: [], PushedFilters: [IsNotNull(product_id)], ReadSchema: struct<product_id:int,product_name:string,category:string>
#                                                                   +- PhotonShuffleExchangeSource
#                                                                      +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#22155]
#                                                                         +- PhotonShuffleExchangeSink hashpartitioning(order_id#11136, 1024)
#                                                                            +- PhotonFilter isnotnull(order_id#11136)
#                                                                               +- PhotonRowToColumnar
#                                                                                  +- FileScan csv [order_id#11136,quantity#11138,unit_price#11139] Batched: false, DataFilters: [isnotnull(order_id#11136)], Format: CSV, Location: InMemoryFileIndex(1 paths)[dbfs:/Volumes/workspace/default/synthetic_e_commerce_data/order_items...., PartitionFilters: [], PushedFilters: [IsNotNull(order_id)], ReadSchema: struct<order_id:int,quantity:int,unit_price:double>
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
'''Write the results to a parquet file'''
most_money_generating_products_women.write.mode("overwrite").parquet("/Volumes/workspace/default/synthetic_e_commerce_outputs/most_money_generating_products_women")

# %%
'''Transformation vs Action'''

# Transformation: Filter the merged dataframe to only include US customers
us_customers = merged_df.filter(merged_df['country'] == 'United States of America')

# Action: Count the number of US customers
us_customers.count()
# Out:
# 19876
